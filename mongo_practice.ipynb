# %% [markdown]
# <h1>MongoDB and JSON: Using Python to Insert Data</h1>
# Data is pulled from the google maps api and inserted into MongoDB.
#
# Before running this code, make sure you've started MongoDB from your shell and connected to it, otherwise your records won't be added.
# <p>On Windows and Mac: https://docs.mongodb.com/manual/mongo/</p>
# <p>On Linux: https://dzone.com/articles/mongodb-commands-cheat-sheet-for-beginners</p>
#
# In this file we will:
# <ol type = '1'>
# <li>Set things up by bringing in our dependencies and connecting to MongoDB </li>
# <li>Insert records using an external JSON file</li>
# <li>Insert records using an API call</li>
# <li>Look up records by ID</li>
# <li>Look up records by string search</li>
# </ol>

# %% [markdown]
# <h3><u>Setup</u?</h3>

# %%
#Dependencies

##create tables
import pandas as pd 

##Tool for converting Zip Codes into Latitude and Longitude coordinates
import pgeocode 

##Use API key
from config import gkey, okey 

##API lookup
import requests

##Reading JSONS
import json 

##Connecting and using MongoDB commands in Python
import pymongo 

##Create artificial delay if lookups cause timeouts
import time

# %%
#Connect to mongo db and create "locations_mdb" database
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

#Create "locations_mdb" database and assign it to a variable
#(note: MongoDB automatically creates a database when you call it, so this will do both)
db = client.locations_mdb

#Creating or swithcing to a collection
clients = db["clients"]  
hotels = db["hotels"]

# %% [markdown]
# <h2>Method 1: Insert Data into MongoDB from an External JSON file</h2>
# <p>Using a randomly generated JSON of fictional clients, we will add records to our collection.</p>

# %%
#Read and Parse the JSON File
myfile=open("generated.json","r")
json_file=json.load(myfile)

#Load into MongoDB
db.hotels.insert_many(json_file)

# %% [markdown]
# <h2>Method 2: Insert Data Directly into MongoDB from the API Pull</h2>

# %%
# If you are looking up data from an API, you might have a table of values that you are using for your queries. Here, we will use zip code data to look up the locations of hotels in San Fransisco.

# Build the zip code reference table in PANDAS
zips_df=pd.read_csv('resources/zip_codes.csv')
zips_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  ZIPCode      Type         County  \
# 0           0             0               0    94102  Standard  San Francisco
# 1           1             1               1    94103  Standard  San Francisco
# 2           2             2               2    94104  Standard  San Francisco
# 3           3             3               3    94105  Standard  San Francisco
# 4           4             4               4    94107  Standard  San Francisco
#
#   Population           Area Code(s)  Latitude  Longitude
# 0     31,176              415 / 510   37.7813  -122.4167
# 1     27,170        415 / 510 / 650   37.7725  -122.4147
# 2        406  415 / 510 / 650 / 628   37.7915  -122.4018
# 3      5,846  415 / 510 / 650 / 628   37.7864  -122.3892
# 4     26,599        415 / 510 / 650   37.7621  -122.3971

# %%
#Create a collection ("hotels_full") in MongoDB and load in data from google api

#Save the api_url to a variable
api_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

#Loop through the zip code data and...
 
#-->save each lat,long pair to a variable.
for index, row in zips_df.iterrows():
    #time.sleep(0.2) #--> This prevents timeouts from pulling API data too quickly.
    target_coordinates = f"{zips_df.loc[index, 'Latitude']},{zips_df.loc[index, 'Longitude']}" 
    target_radius = 50000
    target_type = "lodging"

#--> set up a parameters dictionary
    params = {
        "location": target_coordinates,
        "radius": target_radius,
        "type": target_type,
        "key": gkey}

#--> Request a JSON using our parameters dictionary
    response = requests.get(api_url, params=params).json()
    
#-->Insert the record into MongoDB using our connected database and Mongo's "insert_one" function.
#Note: Remember that we created a variable "db" earlier to represent our database. That's where the "db" below comes from.
    for hotel in response["results"]:
        db.hotels.insert_one(hotel)

# %%
#Build hotels database in PANDAS (to get rid of duplicates)
hotels_df = pd.DataFrame(columns = ['Name', 'Address', "Status", 'Lattitude', "Longitude"]) 

api_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

for index, row in zips_df.iterrows():
    time.sleep(0.5)
    target_coordinates = f"{zips_df.loc[index, 'Latitude']},{zips_df.loc[index, 'Longitude']}" 
    target_radius = 50000
    target_type = "lodging"

# set up a parameters dictionary
    params = {
        "location": target_coordinates,
        "radius": target_radius,
        "type": target_type,
        "key": gkey}

    response = requests.get(api_url, params=params).json()

# create a pandas dataframe of hotels
    for i in range(0,len(response["results"])):
        name=response["results"][i]["name"]
        lat=response["results"][i]["geometry"]["location"]["lat"]
        long=response["results"][i]["geometry"]["location"]["lng"]
        status=response["results"][i]["business_status"]
        address=response["results"][i]['vicinity']

        hotels_df = hotels_df.append({'Name' : name, 'Address' : address, 'Status' : status, "Latitude" :lat, "Longitude": long},  
                ignore_index = True)

# %%
#Drop any duplicates
hotels_df.drop_duplicates(keep='first', inplace=True, ignore_index=True)

# %%
    #Insert entries into MongoDB
    for index, row in hotels_df.iterrows():

        db.hotels.insert_one(
            {
                'Name': f"{hotels_df.loc[index, 'Name']}",
                'Address': f"{hotels_df.loc[index, 'Address']}",
                'Status': f"{hotels_df.loc[index, 'Status']}",
                'Lattitude': f"{hotels_df.loc[index, 'Latitude']}",
                'Longitude': f"{hotels_df.loc[index, 'Longitude']}"

            }
        )

# %%
#Convert the data to a json
with open("data.json", "w") as outfile: 
    json.dump(response, outfile)

# %%
 
# database  
locations_mdb = client["locations_mdb"] 
   
# Created or Switched to collection  
# names: GeeksForGeeks 
Collection = locations_mdb["data"] 
  
# Loading or Opening the json file 
with open('data.json') as file: 
    file_data = json.load(file) 
      
# Inserting the loaded data in the Collection 
# if JSON contains data more than one entry 
# insert_many is used else insert_one is used 
if isinstance(file_data, list): 
   db.data.insert_many(file_data)   
else: 
    db.data.insert_many(file_data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-31-18e9096138ce> in <module>
#       8 # Loading or Opening the json file
#       9 with open('data.json') as file:
# ---> 10     file_data = json.load(file)
#      11
#      12 # Inserting the loaded data in the Collection
#
# ~/anaconda3/envs/DataViz/lib/python3.8/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~/anaconda3/envs/DataViz/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/anaconda3/envs/DataViz/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/envs/DataViz/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
for item in response["results"]:
    locations_mdb.data.insert_one(item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-cc7c6ea3ff17> in <module>
#       1 for item in response["results"]:
# ----> 2     locations_mdb.data.insert_one(item)
#
# NameError: name 'locations_mdb' is not defined

# %%
for item in response["results"]:
    locations_mdb.data.insert_one(item)

# %%
response["results"]
# Out:
# ONAL',
#   'geometry': {'location': {'lat': 37.7771861, 'lng': -122.4231806},
#    'viewport': {'northeast': {'lat': 37.7785474802915,
#      'lng': -122.4217717197085},
#     'southwest': {'lat': 37.7758495197085, 'lng': -122.4244696802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Hayes Valley Inn',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2160,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114331831145864172176">Bert Bräutigam</a>'],
#     'photo_reference': 'ATtYBwLYiTp-lkrFCY7PIhx2HWnvJ90UNS7Jmn5DpK-eTKnYG-ioNc_vEM79RE1F73P45TSFqd97C8JWBptNLLOOj8aXUn1-X_ocK9tWMHgQCai2IgoCAvwRzDA3OYaZ9voUs0_JL34xHmrWm-TZT1YOFb8AhoLluNVIqDzl3dhjkXIArDwJ',
#     'width': 3840}],
#   'place_id': 'ChIJAQ2zvpiAhYARTcxfopA7klQ',
#   'plus_code': {'compound_code': 'QHGG+VP Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHGG+VP'},
#   'rating': 3.9,
#   'reference': 'ChIJAQ2zvpiAhYARTcxfopA7klQ',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 216,
#   'vicinity': '417 Gough Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25d9')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.7775056, 'lng': -122.4242611},
#    'viewport': {'northeast': {'lat': 37.77879718029151,
#      'lng': -122.4228385697085},
#     'southwest': {'lat': 37.77609921970851, 'lng': -122.4255365302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Days Inn by Wyndham San Francisco Downtown/Civic Cntr Area',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 400,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103961891288845402407">Days Inn by Wyndham San Francisco Downtown/Civic Cntr Area</a>'],
#     'photo_reference': 'ATtYBwLWu_5Jqi_tY35qg-D5mW2Mx7plowUZJv19UxoxoXXpUr-n_P4ly73sdi1FhOVhPtHAOaVKvXbW8yVOW-ZE-TIpoeGs5_UuuRkCpumWpF4g_8u8IqYJPftfX2GB5d4TIziOAz155uY0SeNADU5eHIq8rD9MeN6NNn3AjBimoJfjX7jQ',
#     'width': 711}],
#   'place_id': 'ChIJH22heKKAhYARHkkLkiruqX8',
#   'plus_code': {'compound_code': 'QHHG+27 Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHHG+27'},
#   'rating': 4.1,
#   'reference': 'ChIJH22heKKAhYARHkkLkiruqX8',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 325,
#   'vicinity': '465 Grove Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25da')},
#  {'business_status': 'CLOSED_TEMPORARILY',
#   'geometry': {'location': {'lat': 37.7781667, 'lng': -122.4151667},
#    'viewport': {'northeast': {'lat': 37.7795870302915,
#      'lng': -122.4138786197085},
#     'southwest': {'lat': 37.7768890697085, 'lng': -122.4165765802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Hotel Whitcomb',
#   'permanently_closed': True,
#   'photos': [{'height': 465,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106364162916638665696">Ron Brannock</a>'],
#     'photo_reference': 'ATtYBwIh9FH6I1qTf9TyFPf2KM_WLWfi5NBBFIvji1A6DgPmaeevgt6K_waYOZxDkhjA_ScKhCaP2NOS26GmzYCFY3stiA8NGTjky_sAnlHzCCTyWkzIBZdcWjitE3TKfAhTxd7AyzvgNkTCPRybqav1kCAZCEKmLgDmQubbZgKnvRAXyDd-',
#     'width': 720}],
#   'place_id': 'ChIJ1evvfZuAhYAR-beMvqFfSo4',
#   'plus_code': {'compound_code': 'QHHM+7W Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHHM+7W'},
#   'rating': 3.3,
#   'reference': 'ChIJ1evvfZuAhYAR-beMvqFfSo4',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 3144,
#   'vicinity': '1231 Market Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25db')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.7725859, 'lng': -122.4108229},
#    'viewport': {'northeast': {'lat': 37.7741187302915,
#      'lng': -122.4093654197085},
#     'southwest': {'lat': 37.77142076970851, 'lng': -122.4120633802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Civic Center Motor Inn',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3952,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101611343920656901290">Dominik Fahrholz</a>'],
#     'photo_reference': 'ATtYBwLr_6nvObCwybKb8bA_UMgy2S4GpEAlt16gu2OYiRilFzT5taMewkScLX066M0003P5YirQTyqvqIAWr1rtUVgvNR047ybZkDwA2Rma-_Avdrq_wY7V3aQDsl4SoNsW9IFsBDdxNh0HV6O8WM6Bg1M_VwUE7TCWnXADKmUHis24p38Y',
#     'width': 7600}],
#   'place_id': 'ChIJsY43Vyh-j4ARxE8slGieV2w',
#   'plus_code': {'compound_code': 'QHFQ+2M Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHFQ+2M'},
#   'rating': 3.4,
#   'reference': 'ChIJsY43Vyh-j4ARxE8slGieV2w',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 778,
#   'vicinity': '364 9th Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25dc')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.7823889, 'lng': -122.4188905},
#    'viewport': {'northeast': {'lat': 37.78373793029149,
#      'lng': -122.4176207197085},
#     'southwest': {'lat': 37.7810399697085, 'lng': -122.4203186802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'The Embassy Hotel',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 600,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115920371435672938467">The Embassy Hotel</a>'],
#     'photo_reference': 'ATtYBwIgCYLQPc59h07nn7OrTwzKu5S1FvLTNNYOrL39R3g6Hs_qS-AXG0Z0I3ZVGf7XgjpfJENZI0MXmQZekN2yFTXrly39Rdm1paSb6XVDdMHdmffqtnufJdkH-U65C6dKNV5ur3cP_sSlnrPN3ytWlh7hsdxWz4x7B_SnU7AEm57SRmEL',
#     'width': 800}],
#   'place_id': 'ChIJkaxkTZeAhYARKUGHC1dMXAI',
#   'plus_code': {'compound_code': 'QHJJ+XC Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHJJ+XC'},
#   'rating': 3,
#   'reference': 'ChIJkaxkTZeAhYARKUGHC1dMXAI',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 373,
#   'vicinity': '610 Polk Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25dd')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.7789625, 'lng': -122.4109849},
#    'viewport': {'northeast': {'lat': 37.7803258302915,
#      'lng': -122.4094866697085},
#     'southwest': {'lat': 37.7776278697085, 'lng': -122.4121846302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Good Hotel',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3265,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116824879334163239235">Toni Serrano</a>'],
#     'photo_reference': 'ATtYBwIMyTrUobtQcmoanpidt67u4L0CG_1ydRmU3M41hict6OhLOVyHww9YJ0D8KcrznQVYBOjAyJm09Q9U5srHcsonvXBwQm6lKIk4N_qQq7e4lTC8312fmA3fWtBxYyHqeXmwGNd6Cg7OLUQ9NP2kVo4rlOd4F2M5oytQiKbgavVRETtb',
#     'width': 4898}],
#   'place_id': 'ChIJ9UxCZYOAhYARCJVW78FgsBs',
#   'plus_code': {'compound_code': 'QHHQ+HJ Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHHQ+HJ'},
#   'rating': 3.3,
#   'reference': 'ChIJ9UxCZYOAhYARCJVW78FgsBs',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 791,
#   'vicinity': '112 7th Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25de')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.78055560000001, 'lng': -122.4119444},
#    'viewport': {'northeast': {'lat': 37.7817290802915,
#      'lng': -122.4104755197085},
#     'southwest': {'lat': 37.7790311197085, 'lng': -122.4131734802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Aida Plaza',
#   'photos': [{'height': 2322,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101333830967962817389">Patricia Martins</a>'],
#     'photo_reference': 'ATtYBwIqXK2vU5La0Wkg83YhUquqLy2LGiHGtQYH3aGfu_4usAak4UhifsPRD69hb9HQC6TySTqtaeRCowEmtBxGUqYWEe3Q33v4q_yDS5mbdjD6uSxrGkpo25YEkya64k_j6HBMnLvex9K78S5uLL_AA4TLY2pVr9mbs82Y-5Z1VfWlum8j',
#     'width': 4128}],
#   'place_id': 'ChIJ-4Q_xoSAhYARK7VKNJdoKKM',
#   'plus_code': {'compound_code': 'QHJQ+66 Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHJQ+66'},
#   'rating': 3,
#   'reference': 'ChIJ-4Q_xoSAhYARK7VKNJdoKKM',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 430,
#   'vicinity': '1087 Market Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25df')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.783058, 'lng': -122.4181435},
#    'viewport': {'northeast': {'lat': 37.7845088802915,
#      'lng': -122.4166973197085},
#     'southwest': {'lat': 37.78181091970851, 'lng': -122.4193952802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Phoenix Hotel',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1033,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103463886224419778090">Phoenix Hotel</a>'],
#     'photo_reference': 'ATtYBwIghbuaYT8uSMLD0lwXhuQ4f6KvpPtbYGwC_fc8D5EsxMHHSAfH3iSZnCHVBarQ6-ONrQbUXzDGcTuI9nKn3I3Uv7lFpOrtBzu6RKMvE-xOWQ9gRjcxnouBU4K3utRzjrA7qnhPYPj0sHZIfOX8WPm53qM_4IVMGBZLxvPtv064Tg7g',
#     'width': 1550}],
#   'place_id': 'ChIJ70zQuZCAhYARdKqXrH-M97s',
#   'plus_code': {'compound_code': 'QHMJ+6P Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHMJ+6P'},
#   'rating': 4.3,
#   'reference': 'ChIJ70zQuZCAhYARdKqXrH-M97s',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 599,
#   'vicinity': '601 Eddy Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25e0')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.7788006, 'lng': -122.4102065},
#    'viewport': {'northeast': {'lat': 37.7800915302915,
#      'lng': -122.4089007697085},
#     'southwest': {'lat': 37.7773935697085, 'lng': -122.4115987302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Americania Hotel',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 562,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100145436600387533351">Americania Hotel</a>'],
#     'photo_reference': 'ATtYBwIOTcP_RcwdZQbaMZZTWtVohQ1dY6DLosUkyLg6rctJ7HDe47s9-n_-Q80b2Bq8o0IYWcNXWQOdEEDiwqEOXZYw1NEkHLff5CbcuRoehCFTH6mgFNqXEmUK7LaEvk6s0yE54AC-BcmU7kY3vMqB36xMFEBscBrxXxVHKLmiW8e_8n7o',
#     'width': 1000}],
#   'place_id': 'ChIJOTbxc4OAhYARrK82JwxWZFY',
#   'plus_code': {'compound_code': 'QHHQ+GW Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHHQ+GW'},
#   'rating': 3.7,
#   'reference': 'ChIJOTbxc4OAhYARrK82JwxWZFY',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1144,
#   'vicinity': '121 7th Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25e1')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.7756777, 'lng': -122.4086321},
#    'viewport': {'northeast': {'lat': 37.7770324302915,
#      'lng': -122.4072289697085},
#     'southwest': {'lat': 37.7743344697085, 'lng': -122.4099269302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Americas Best Value Inn & Suites SOMA',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1028,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116372397723513823387">Americas Best Value Inn &amp; Suites SOMA</a>'],
#     'photo_reference': 'ATtYBwKItyR7dn_0kg4wAivwTLwj-w8itxclyLOI3QZg3zJ-w9QNf5p7Lk62hiZ7SKUVoelunev1faz9IEX6AQvAwCqoHbmT3C5fFPNGBmsPknL-vg2ohhiTx-JvGG4zLVHHRDkBPi03aEXqrSzjuIDxsh7t_qdx7Q_8sQjen2qk-Vo4Oh94',
#     'width': 1536}],
#   'place_id': 'ChIJUyKWdIKAhYARwbu-VpwOBYM',
#   'plus_code': {'compound_code': 'QHGR+7G Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHGR+7G'},
#   'rating': 3.1,
#   'reference': 'ChIJUyKWdIKAhYARwbu-VpwOBYM',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 319,
#   'vicinity': '10 Hallam Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25e2')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.78391409999999, 'lng': -122.417319},
#    'viewport': {'northeast': {'lat': 37.78536593029149,
#      'lng': -122.4157170697085},
#     'southwest': {'lat': 37.78266796970849, 'lng': -122.4184150302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Cova Hotel',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2912,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112670559022802385984">Cova Hotel</a>'],
#     'photo_reference': 'ATtYBwKA_P6alVcM_b2Qr1LW1yDFQWE4Ct5P5sb0jCNwchiJR6NTZRl6nH-_TxPTKOjROnSeC8TK9wGlCNaaolUkMKR4oQEtBqvDnhpLw2vPv_sploIKFdB-oYf7r5Q6Wi0lUcWWAbU7utr3Q9QFe7aZJ98w44OUWVaT75DqfpLO7sj_GOdx',
#     'width': 4368}],
#   'place_id': 'ChIJRWpX6JCAhYAR0-VkB4jNLIw',
#   'plus_code': {'compound_code': 'QHMM+H3 Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHMM+H3'},
#   'rating': 3.8,
#   'reference': 'ChIJRWpX6JCAhYAR0-VkB4jNLIw',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 891,
#   'vicinity': '655 Ellis Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25e3')},
#  {'business_status': 'CLOSED_TEMPORARILY',
#   'geometry': {'location': {'lat': 37.7840703, 'lng': -122.4174477},
#    'viewport': {'northeast': {'lat': 37.7855266302915,
#      'lng': -122.4160943697085},
#     'southwest': {'lat': 37.7828286697085, 'lng': -122.4187923302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'HI San Francisco City Center Hostel',
#   'permanently_closed': True,
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110549978092240296811">Syed Shah</a>'],
#     'photo_reference': 'ATtYBwK-OveSZtrtL3PNhPbMtKScXHLSPE9O3b3ZNdthCMSjw67i6rRbGNxLfBsFIeP6rGlwA9sBMG1CFQ_Of20Q-IdtF2SCBAgasILGUUWpu1aiwxlmME0fbNIaWsdmicNmHJudwUfcU1B2LyJUC8Q_9hW4J2X8JQtcltI544PYcbfrMcvu',
#     'width': 4608}],
#   'place_id': 'ChIJa2Od25CAhYARrDptsKqJ8ao',
#   'plus_code': {'compound_code': 'QHMM+J2 Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHMM+J2'},
#   'rating': 4.2,
#   'reference': 'ChIJa2Od25CAhYARrDptsKqJ8ao',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 732,
#   'vicinity': '685 Ellis Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25e4')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.78444439999999, 'lng': -122.4188889},
#    'viewport': {'northeast': {'lat': 37.78569013029149,
#      'lng': -122.4177187697085},
#     'southwest': {'lat': 37.7829921697085, 'lng': -122.4204167302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Civic Center Inn',
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107298113788977086003">vali lightman</a>'],
#     'photo_reference': 'ATtYBwJ3WxbhbrtV9UrMSNJuBCL4GJGQqG3eTxIrCHga-IKhqDHj8ltUyLqcIq_OcX4KTvyRZgP4mmsx1d-TtmB14YFKvlc34q_qeKQxt8wKzwq5kR6P5K-Yg8ZMjDARMf5-OqUlMQCzA915nehmO4FdQISNclH-o2DTEDJp9WpVrGCN9WO2',
#     'width': 4032}],
#   'place_id': 'ChIJo_Vt2JaAhYARUSDJRJREm88',
#   'plus_code': {'compound_code': 'QHMJ+QC Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHMJ+QC'},
#   'rating': 2.4,
#   'reference': 'ChIJo_Vt2JaAhYARUSDJRJREm88',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 856,
#   'vicinity': '790 Ellis Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25e5')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.7856153, 'lng': -122.4201363},
#    'viewport': {'northeast': {'lat': 37.7870817802915,
#      'lng': -122.4187894697085},
#     'southwest': {'lat': 37.7843838197085, 'lng': -122.4214874302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'The Monarch Hotel',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 484,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105332658296655785586">The Monarch Hotel</a>'],
#     'photo_reference': 'ATtYBwKMYuawoc2OYZaO7KAFPBeSMQDFqEbJG7aT-E0Ao1M7-JqlDTW8aXK4fkgaqT8VdfW1Uy5SAXxOiBp8kh9wyGqks0eyyG-jAECo3s_AN3Abard_99EGfTk8ugX1r6vEc2emR0Le52O0Onzz-C0rvMHE_-ioWaWMQUcl6m1TWOJnXYH6',
#     'width': 860}],
#   'place_id': 'ChIJIyLZmJaAhYARloWv0tc5Kyg',
#   'plus_code': {'compound_code': 'QHPH+6W Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHPH+6W'},
#   'rating': 3.2,
#   'reference': 'ChIJIyLZmJaAhYARloWv0tc5Kyg',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 520,
#   'vicinity': '1015 Geary Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25e6')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.7857507, 'lng': -122.4177262},
#    'viewport': {'northeast': {'lat': 37.7872958802915,
#      'lng': -122.4164806197085},
#     'southwest': {'lat': 37.7845979197085, 'lng': -122.4191785802915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Motel 6 San Francisco, CA',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1920,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105110070907817414364">Motel 6 San Francisco CA</a>'],
#     'photo_reference': 'ATtYBwKDmDSGuU3yizTQEKOZh3IgKGnxq08Jr2t3zkGI5BuSzZQbgLRJaXjTfGu0uI7saq6feS1-DR1I2nS4A_JrTlIwZLowcY4k_THxARkzqPG6qQAcWGqroIiq1NrWgyjk9oQcDA6moeNZqEYfg1w45tv5V1b3wmAAeBhMbLu9i3FKlsh_',
#     'width': 2879}],
#   'place_id': 'ChIJ800ISJGAhYARgJz1fhF84_c',
#   'plus_code': {'compound_code': 'QHPJ+8W Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHPJ+8W'},
#   'rating': 3.5,
#   'reference': 'ChIJ800ISJGAhYARgJz1fhF84_c',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1083,
#   'vicinity': '895 Geary Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25e7')},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 37.7845106, 'lng': -122.4095759},
#    'viewport': {'northeast': {'lat': 37.7858818802915,
#      'lng': -122.4081212697085},
#     'southwest': {'lat': 37.7831839197085, 'lng': -122.4108192302915}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Hotel Bijou',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2400,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111604554227145863383">Hotel Bijou</a>'],
#     'photo_reference': 'ATtYBwLQK1n5i6SlbxO2H-DNWqG93NVE8jJmYb1tNtRDgDyvk5f6k-W_T_xqV8NJIxouBSCRYg1CzA8wCtSSTj5ETu68cCQ5hYMOAmyrI1byZpUfUXDgV36_xXZqTXbNZJhWFvKGpdpp8Dr0WTt4TKjqpTALRng0HDc95ccXjGHDfOmlIzlJ',
#     'width': 3600}],
#   'place_id': 'ChIJLYHZhoWAhYAR4KekZbZtNK0',
#   'plus_code': {'compound_code': 'QHMR+R5 Central Embarcadero Piers Historic District, CA, USA',
#    'global_code': '849VQHMR+R5'},
#   'rating': 3.5,
#   'reference': 'ChIJLYHZhoWAhYAR4KekZbZtNK0',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 440,
#   'vicinity': '111 Mason Street, San Francisco',
#   '_id': ObjectId('5fc84dacee717099b4cd25e8')}]

# %%
#Retrieve your data
